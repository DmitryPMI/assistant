# %% [markdown]
# ## Функция для обрезки аудио

# %%
from pydub import AudioSegment
from warnings import filterwarnings
filterwarnings('ignore')

# %%
def audio_crop(start, end, old_file, new_file, fmt='wav'):
    try:
        wav_file = AudioSegment.from_file(old_file)
        crop_file = wav_file[start:end]
        crop_file.export(new_file, format=fmt)
        print('success! ' + old_file)
    except Exception as e:
        print('error! ' + old_file)

audio_crop(0, 2000, '5_mc.wav', '55.wav')
# Out:
# success! 5_mc.wav

# %% [markdown]
# ## Обработка аудио

# %%
for i in range(0, 500000, 4000):
    audio_crop(i, i + 4000, 'new_data/mh/Сергей_Бурунов[BestVideoConverter.net].wav', 'new_data/mh/1mh' + str(i) + '.wav')
# Out:
# success! new_data/mh/Сергей_Бурунов[BestVideoConverter.net].wav
# success! new_data/mh/Сергей_Бурунов[BestVideoConverter.net].wav
# success! new_data/mh/Сергей_Бурунов[BestVideoConverter.net].wav
# success! new_data/mh/Сергей_Бурунов[BestVideoConverter.net].wav
# success! new_data/mh/Сергей_Бурунов[BestVideoConverter.net].wav
# success! new_data/mh/Сергей_Бурунов[BestVideoConverter.net].wav
# success! new_data/mh/Сергей_Бурунов[BestVideoConverter.net].wav
# success! new_data/mh/Сергей_Бурунов[BestVideoConverter.net].wav
# success! new_data/mh/Сергей_Бурунов[BestVideoConverter.net].wav
# success! new_data/mh/Сергей_Бурунов[BestVideoConverter.net].wav
# success! new_data/mh/Сергей_Бурунов[BestVideoConverter.net].wav
# success! new_data/mh/Сергей_Бурунов[BestVideoConverter.net].wav
# success! new_data/mh/Сергей_Бурунов[BestVideoConverter.net].wav
# success! new_data/mh/Сергей_Бурунов[BestVideoConverter.net].wav
# success! new_data/mh/Сергей_Бурунов[BestVideoConverter.net].wav
# ...

# %%
Грустные_видео_со_смыслом_до_слёз_про_любовь[BestVideoConverter.net].wav

# %%
for i in range(0, 200000, 4000):
    audio_crop(i, i + 4000, 'new_data/ms/Грустные_видео_со_смыслом_до_слёз_про_любовь[BestVideoConverter.net].wav', 'new_data/ms/1ms' + str(i) + '.wav')
# Out:
# success! new_data/ms/Грустные_видео_со_смыслом_до_слёз_про_любовь[BestVideoConverter.net].wav
# success! new_data/ms/Грустные_видео_со_смыслом_до_слёз_про_любовь[BestVideoConverter.net].wav
# success! new_data/ms/Грустные_видео_со_смыслом_до_слёз_про_любовь[BestVideoConverter.net].wav
# success! new_data/ms/Грустные_видео_со_смыслом_до_слёз_про_любовь[BestVideoConverter.net].wav
# success! new_data/ms/Грустные_видео_со_смыслом_до_слёз_про_любовь[BestVideoConverter.net].wav
# success! new_data/ms/Грустные_видео_со_смыслом_до_слёз_про_любовь[BestVideoConverter.net].wav
# success! new_data/ms/Грустные_видео_со_смыслом_до_слёз_про_любовь[BestVideoConverter.net].wav
# success! new_data/ms/Грустные_видео_со_смыслом_до_слёз_про_любовь[BestVideoConverter.net].wav
# success! new_data/ms/Грустные_видео_со_смыслом_до_слёз_про_любовь[BestVideoConverter.net].wav
# success! new_data/ms/Грустные_видео_со_смыслом_до_слёз_про_любовь[BestVideoConverter.net].wav
# ...

# %%
for i in range(0, 500000, 4000):
    audio_crop(i, i + 4000, 'new_data/fc/1.wav', 'new_data/fc/1fc' + str(i) + '.wav')
# Out:
# success! new_data/fc/1.wav
# success! new_data/fc/1.wav
# success! new_data/fc/1.wav
# success! new_data/fc/1.wav
# success! new_data/fc/1.wav
# success! new_data/fc/1.wav
# success! new_data/fc/1.wav
# success! new_data/fc/1.wav
# success! new_data/fc/1.wav
# success! new_data/fc/1.wav
# success! new_data/fc/1.wav
# success! new_data/fc/1.wav
# success! new_data/fc/1.wav
# success! new_data/fc/1.wav
# success! new_data/fc/1.wav
# success! new_data/fc/1.wav
# success! new_data/fc/1.wav
# success! new_data/fc/1.wav
# success! new_data/fc/1.wav
# success! new_data/fc/1.wav
# success! new_data/fc/1.wav
# success! new_data/fc/1.wav
# success! new_data/fc/1.wav
# success! new_data/fc/1.wav
# success! new_data/fc/1.wav
# success! new_data/fc/1.wav
# success! new_data/fc/1.wav
# success! new_data/fc/1.wav
# success! new_data/fc/1.wav
# success! new_data/fc/1.wav
# success! new_data/fc/1.wav
# success! new_data/fc/1.wav
# success! new_data/fc/1.wav
# success! new_data/fc/1.wav
# ...

# %%
for i in range(0, 500000, 4000):
    audio_crop(i, i + 4000, 'new_data/mc/1.wav', 'new_data/mc/1mc' + str(i) + '.wav')
# Out:
# success! new_data/mc/1.wav
# success! new_data/mc/1.wav
# success! new_data/mc/1.wav
# success! new_data/mc/1.wav
# success! new_data/mc/1.wav
# success! new_data/mc/1.wav
# success! new_data/mc/1.wav
# success! new_data/mc/1.wav
# success! new_data/mc/1.wav
# success! new_data/mc/1.wav
# success! new_data/mc/1.wav
# success! new_data/mc/1.wav
# success! new_data/mc/1.wav
# success! new_data/mc/1.wav
# success! new_data/mc/1.wav
# success! new_data/mc/1.wav
# success! new_data/mc/1.wav
# success! new_data/mc/1.wav
# success! new_data/mc/1.wav
# success! new_data/mc/1.wav
# success! new_data/mc/1.wav
# success! new_data/mc/1.wav
# success! new_data/mc/1.wav
# success! new_data/mc/1.wav
# success! new_data/mc/1.wav
# success! new_data/mc/1.wav
# success! new_data/mc/1.wav
# success! new_data/mc/1.wav
# success! new_data/mc/1.wav
# success! new_data/mc/1.wav
# success! new_data/mc/1.wav
# success! new_data/mc/1.wav
# success! new_data/mc/1.wav
# success! new_data/mc/1.wav
# ...

# %%
for i in range(0, 500000, 4000):
    audio_crop(i, i + 4000, 'new_data/fs/mariana.wav', 'new_data/fs/1fs' + str(i) + '.wav')
# Out:
# success! new_data/fs/mariana.wav
# success! new_data/fs/mariana.wav
# success! new_data/fs/mariana.wav
# success! new_data/fs/mariana.wav
# success! new_data/fs/mariana.wav
# success! new_data/fs/mariana.wav
# success! new_data/fs/mariana.wav
# success! new_data/fs/mariana.wav
# success! new_data/fs/mariana.wav
# success! new_data/fs/mariana.wav
# success! new_data/fs/mariana.wav
# success! new_data/fs/mariana.wav
# success! new_data/fs/mariana.wav
# success! new_data/fs/mariana.wav
# success! new_data/fs/mariana.wav
# success! new_data/fs/mariana.wav
# success! new_data/fs/mariana.wav
# success! new_data/fs/mariana.wav
# success! new_data/fs/mariana.wav
# success! new_data/fs/mariana.wav
# success! new_data/fs/mariana.wav
# success! new_data/fs/mariana.wav
# success! new_data/fs/mariana.wav
# success! new_data/fs/mariana.wav
# success! new_data/fs/mariana.wav
# success! new_data/fs/mariana.wav
# success! new_data/fs/mariana.wav
# success! new_data/fs/mariana.wav
# ...

# %%
for i in range(0, 150000, 4000):
    audio_crop(i, i + 4000, 'new_data/fh/1.wav', 'new_data/fh/1fh' + str(i) + '.wav')
# Out:
# success! new_data/fh/1.wav
# success! new_data/fh/1.wav
# success! new_data/fh/1.wav
# success! new_data/fh/1.wav
# success! new_data/fh/1.wav
# success! new_data/fh/1.wav
# success! new_data/fh/1.wav
# success! new_data/fh/1.wav
# success! new_data/fh/1.wav
# success! new_data/fh/1.wav
# success! new_data/fh/1.wav
# success! new_data/fh/1.wav
# success! new_data/fh/1.wav
# success! new_data/fh/1.wav
# success! new_data/fh/1.wav
# success! new_data/fh/1.wav
# success! new_data/fh/1.wav
# success! new_data/fh/1.wav
# success! new_data/fh/1.wav
# success! new_data/fh/1.wav
# success! new_data/fh/1.wav
# success! new_data/fh/1.wav
# success! new_data/fh/1.wav
# success! new_data/fh/1.wav
# success! new_data/fh/1.wav
# success! new_data/fh/1.wav
# success! new_data/fh/1.wav
# success! new_data/fh/1.wav
# success! new_data/fh/1.wav
# success! new_data/fh/1.wav
# success! new_data/fh/1.wav
# success! new_data/fh/1.wav
# success! new_data/fh/1.wav
# success! new_data/fh/1.wav
# ...

# %%
for i in range(0, 150000, 4000):
    audio_crop(i, i + 4000, 'new_data/ma/1.wav', 'new_data/ma/1ma' + str(i) + '.wav')
# Out:
# success! new_data/ma/1.wav
# success! new_data/ma/1.wav
# success! new_data/ma/1.wav
# success! new_data/ma/1.wav
# success! new_data/ma/1.wav
# success! new_data/ma/1.wav
# success! new_data/ma/1.wav
# success! new_data/ma/1.wav
# success! new_data/ma/1.wav
# success! new_data/ma/1.wav
# success! new_data/ma/1.wav
# success! new_data/ma/1.wav
# success! new_data/ma/1.wav
# success! new_data/ma/1.wav
# success! new_data/ma/1.wav
# success! new_data/ma/1.wav
# success! new_data/ma/1.wav
# success! new_data/ma/1.wav
# success! new_data/ma/1.wav
# success! new_data/ma/1.wav
# success! new_data/ma/1.wav
# success! new_data/ma/1.wav
# success! new_data/ma/1.wav
# success! new_data/ma/1.wav
# success! new_data/ma/1.wav
# success! new_data/ma/1.wav
# success! new_data/ma/1.wav
# success! new_data/ma/1.wav
# success! new_data/ma/1.wav
# success! new_data/ma/1.wav
# success! new_data/ma/1.wav
# success! new_data/ma/1.wav
# success! new_data/ma/1.wav
# success! new_data/ma/1.wav
# ...

# %%
for i in range(0, 150000, 4000):
    audio_crop(i, i + 4000, 'new_data/fa/1.wav', 'new_data/fa/1fa' + str(i) + '.wav')
# Out:
# success! new_data/fa/1.wav
# success! new_data/fa/1.wav
# success! new_data/fa/1.wav
# success! new_data/fa/1.wav
# success! new_data/fa/1.wav
# success! new_data/fa/1.wav
# success! new_data/fa/1.wav
# success! new_data/fa/1.wav
# success! new_data/fa/1.wav
# success! new_data/fa/1.wav
# success! new_data/fa/1.wav
# success! new_data/fa/1.wav
# success! new_data/fa/1.wav
# success! new_data/fa/1.wav
# success! new_data/fa/1.wav
# success! new_data/fa/1.wav
# success! new_data/fa/1.wav
# success! new_data/fa/1.wav
# success! new_data/fa/1.wav
# success! new_data/fa/1.wav
# success! new_data/fa/1.wav
# success! new_data/fa/1.wav
# success! new_data/fa/1.wav
# success! new_data/fa/1.wav
# success! new_data/fa/1.wav
# success! new_data/fa/1.wav
# success! new_data/fa/1.wav
# success! new_data/fa/1.wav
# success! new_data/fa/1.wav
# success! new_data/fa/1.wav
# success! new_data/fa/1.wav
# success! new_data/fa/1.wav
# success! new_data/fa/1.wav
# success! new_data/fa/1.wav
# ...
